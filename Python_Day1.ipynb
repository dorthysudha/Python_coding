# %% [markdown]
# # Student Profile Creator

# %%
# Student Profile Creator
student_name = 'Asha'
student_age = 19
fav_subject = ['Maths', 'Computer','Physics']

print('-----student information---------')
print("student name :",student_name)
print("student age :",student_age)
print (fav_subject)

favourite_subject = input('enter fav_subject :')
fav_subject.append(favourite_subject)
print("Updated favourite_subject:")
print(fav_subject)
# Out:
# -----student information---------
# student name : Asha
# student age : 19
# ['Maths', 'Computer', 'Physics']
# enter fav_subject :chemistry
# Updated favourite_subject:
# ['Maths', 'Computer', 'Physics', 'chemistry']
